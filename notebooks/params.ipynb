# %% [markdown]
# <h1><strong> 모델 하이퍼파라미터 저장 </strong></h1>
# <br>
#
# <hr>
#
# <br>
# <h2> 1. Introduction </h2>
#  <p style="font-size:16px">개요 : 본 노트북은 이미지의 패치 별 최적의 샤프닝 강도 배열과 밝기, 밝기 변화 진폭, 고주파수 비율을 훈련 세트로 한 데이터셋을 활용하여 XGBoost로 학습시키는 과정을 기록한 리포트이다.
#  <p style="font-size:16px">목표 : 이미지 패치 특징(평균, 표준편차, 고주파 비율)을 기반으로 최적의 샤프닝 강도(k)를 예측하는 XGBoost 회귀 모델을 학습시키고, 학습된 모델을 파일로 저장한다.</p>
#
# <br>
# <hr>
# <br>
# <h2> 2. 하이퍼파라미터  </h2>

# %%
import random

train_dir = "./images"
input_dir = "./image_input/new_img.png"
output_dir = "./result"

img_extensions = (".png", ".jpg", ".jpeg")

# LQ Creation Parameters for Downsampling HQ
DOWNSCALE = 0.5
LQ_BLUR_SIGMA = random.uniform(0.5, 3.5)

# Unsharp Mask
k_values = [x * 0.1 for x in range(0, 51)]
patch = 32
stride = 16

# SSIM vs PSNR Weights
SSIM_WEIGHT = 0.7
PSNR_WEIGHT = 0.3

# %% [markdown]
# <p style="font-size:16px">
#    위 함수는 XGBoost 모델의 하이퍼파라미터, 경로 등의 필요한 정보를 저장한다.
#
#    모델을 훈련시킬 이미지들의 경로는 /images,
#    훈련된 모델로 시연해볼 이미지의 경로는 /image_input/new_img.png,
#    하이퍼파라미터 그리드탐색 결과, 보정된 이미지, 훈련 데이터셋 등의 경로는 /result로 지정했다.
#
#    img 확장자 형식, 저해상도 이미지로 다운샘플링할 때 필요한 강도와 블러 시그마 강도를 랜덤 지정하고,
#    샤프닝강도 k가 0.0부터 5.0까지 0.1 단위로 조절되며 탐색하도록 범위를 설정했다.
#
#    훈련 데이터를 생성하기 위한 이미지 패치(patch)의 크기는 32, 패치 간 이동 간격(stride)은 16으로 정의했다.
#
#    마지막으로 최적의 k값을 선정하기 위한 화질 평가 지표로는 구조적 유사도(SSIM)와 최대 신호 대 잡음비(PSNR)를 사용하며, 각각 0.7과 0.3의 가중치를 부여해 종합적으로 판단하도록 구성했다.
# </p>
